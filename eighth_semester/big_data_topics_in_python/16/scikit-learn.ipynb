# %%
# !pip install scikit-learn matplotlib
# Out:
# /bin/pip:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import load_entry_point
# Requirement already satisfied: scikit-learn in /home/dsilva/.local/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: matplotlib in /home/dsilva/.local/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /home/dsilva/.local/lib/python3.8/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.5.0 in /home/dsilva/.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/dsilva/.local/lib/python3.8/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/dsilva/.local/lib/python3.8/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib) (20.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (7.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /home/dsilva/.local/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/dsilva/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib) (3.20.0)

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
X, y = make_classification(n_samples=100, random_state=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=1, max_iter=300)

# %%
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
tree.plot_tree(clf.fit(X_train, y_train))
# Out:
# [Text(0.4444444444444444, 0.9, 'x[1] <= -0.441\ngini = 0.5\nsamples = 75\nvalue = [38, 37]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.5555555555555556, 0.7, 'x[13] <= 1.694\ngini = 0.097\nsamples = 39\nvalue = [2, 37]'),
#  Text(0.3333333333333333, 0.5, 'x[18] <= -1.711\ngini = 0.053\nsamples = 37\nvalue = [1, 36]'),
#  Text(0.2222222222222222, 0.3, 'x[5] <= 0.045\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 35\nvalue = [0, 35]'),
#  Text(0.7777777777777778, 0.5, 'x[14] <= 1.643\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]')]

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=1, max_iter=300)
clf.fit(X_train, y_train)
print("Detailed Prediction: ",clf.predict_proba(X_test[:1]))
print("Prediction: ", clf.predict(X_test[:5, :]))
print("Model Accuracy: ", clf.score(X_test, y_test))
# Out:
# Detailed Prediction:  [[0.03838405 0.96161595]]
# Prediction:  [1 0 1 0 1]
# Model Accuracy:  0.88
